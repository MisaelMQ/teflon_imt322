# %% [markdown]
# # <span style="color:#1b41a1">**STRESS ANALYSIS**</span>

# %% [markdown]
# ### Applying forces of gravity
# In La Paz the gravitational constant is 9.775 m/s$^2$.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Taking Fources External

# %% [markdown]
# ![image.png](data:image/png;base64,...)
